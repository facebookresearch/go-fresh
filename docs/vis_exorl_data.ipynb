# %%
import os
import numpy as np

from IPython.display import HTML, Video

# %%
data_dir = "/checkpoint/linamezghani/offline-gcrl/data/quadruped/aps"
buffer_dir = os.path.join(data_dir, 'buffer')
video_dir = os.path.join(data_dir, 'video')
print(video_dir)
# Out:
# /checkpoint/linamezghani/offline-gcrl/data/quadruped/aps/video

# %%
ep_list = os.listdir(video_dir)

# %%
i = np.random.randint(len(ep_list))

video_file = os.path.join(video_dir, ep_list[i])

Video(video_file, embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
i = np.random.randint(len(ep_list))

video_file = os.path.join(video_dir, ep_list[i])

Video(video_file, embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
